# %% [markdown]
# # Scrape Problems
# In this notebook we will use the selenium web driver to scrape problem data from the moonboard website. The general approach is to scan through each page of problems on the website and extract the urls to each individual problem. We then visit each url individually and extract the holds used for each problem.

# %%
import os
import copy
import json
import time
import string
import pickle

from bs4 import BeautifulSoup
from selenium import webdriver

# %% [markdown]
# ## Helper functions

# %%
def find_element(browser, tag_name, attribute, value, num_tries=10, sleep_val=1):
    """
    Finds elements of a given tag name, attribute, and value on a browser page
    """
    elem = None
    for i in range(num_tries):
        try:
            elems = browser.find_elements_by_tag_name(tag_name)
            for e in elems:
                if e.get_attribute(attribute) == value:
                    elem = e
                    break
            if elem is not None:
                break
        except:
            time.sleep(sleep_val)
            continue
    if elem is None:
        print('Failed to find ' + str(attribute) + ' ' + str(value))
    return elem

def find_and_click(browser, tag_name, attribute, value):
    """
    Finds a specific HTML element and clicks on it
    """
    elem = find_element(browser, tag_name, attribute, value)         
    elem.click()         
    return elem

def process_all_problems(browser, problems_dict):
    """
    For a given page, collect all problems' metadata
    """
    problems, data_ids = get_problems(browser)
    for i, problem in enumerate(problems):
        if data_ids[i] in problems_dict:
            continue
        problems_dict[data_ids[i]] = get_problem_meta(problem)

    return problems_dict

def get_problems(browser):
    """
    For a single page, get problem IDs and problem objects
    """
    problems = []
    data_ids = []
    elems = browser.find_elements_by_tag_name('tr')

    for e in elems:
        uid = e.get_attribute('data-uid')
        check1 = uid is not None
        check2 = e.get_attribute('onclick') == 'problemSelected();'
        if check1 and check2:
            data_ids.append(uid)
            problems.append(e)

    return problems, data_ids

def get_problem_meta(problem):
    """
    Finds metadata tags from a problem object
    """
    meta = {}

    h3 = problem.find_elements_by_tag_name('h3')[0]
    meta['problem_name'] = h3.text
    meta['info'] = [p.text for p in problem.find_elements_by_tag_name('p')]
    meta['url'] = h3.find_elements_by_tag_name('a')[0].get_attribute('href')

    

    return meta

def click_next_page(browser, current_page=1):
    """
    Clicks on button to access next page of routes
    """
    next_page = current_page + 1
    page_elem = find_and_click(browser, 'a', 'data-page', str(next_page))
    return page_elem

# %% [markdown]
# ## 1. Open browser, login, and navigate to the problems page.

# %%
# Load an incognito Chrome browser

options = webdriver.ChromeOptions()
options.add_argument('--incognito')
driver_path = r"C:\Users\Tom\Downloads\chromedriver_win32\chromedriver.exe"

browser = webdriver.Chrome(executable_path=driver_path, options=options)
browser.set_window_size(1500, 910)

# %%
# load moonboard website    
browser.get('https://moonboard.com/')


# Click login area
a_elems = browser.find_elements_by_tag_name('a')
for a in a_elems:
    if a.text == 'LOGIN/REGISTER':
        login_elem = a
        break
if login_elem is None:
    print('Failed to find Login Button')
else:
    login_elem.click()


# Fill in credentials and login   

username = ''
password = ''

username_elem = None
password_elem = None
input_field_elems = browser.find_elements_by_tag_name('input')

# Iterate through input field elements
for i in input_field_elems:
    if i.get_attribute('placeholder') == 'Username':
        username_elem = i
    if i.get_attribute('placeholder') == 'Password':
        password_elem = i

# Populate fields
if username_elem is not None and password_elem is not None:
    username_elem.send_keys(username)
    password_elem.send_keys(password)


# click login
find_and_click(browser, 'button', 'type', 'submit')
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="baf55c85f7f74e3981f30be061764310", element="439f6c22-8cac-4e6f-bf84-89b1d0a3e28b")>

# %%
#click view problems
click_problems = find_and_click(browser, 'a', 'id', 'lProblems')
click_view = find_and_click(browser, 'li', 'id', 'm-viewproblem')


    


# Finds hold setup dropdown
target_elem = None
elems = browser.find_elements_by_tag_name('select')
for e in elems:
    if e.get_attribute('id') == 'Holdsetup':
        target_elem = e
        break


# Selects appropriate dropdown item
elems = target_elem.find_elements_by_tag_name('option')
target_elem = None
for e in elems:
    if e.text == 'MoonBoard Masters 2017':
        target_elem = e


# Select hold configuration
target_elem.click()

# %% [markdown]
# ## 2. Click through each page of problems and extract problem urls.
# Put num_pages = -1 to process all pages

# %%
problems_dict = {}

page_cnt = 0
found_page = True
current_page = 1
num_pages = 10   
while found_page:
    page_cnt += 1
    
    for i in range(20):
            try:
                problems_dict = process_all_problems(browser, problems_dict)
                print('Processed page: %s!' % current_page)
                break
            except:
                print('Failed to process problems on page ' + str(current_page))
                time.sleep(1)
                continue
                 

    page_elem = None
    for i in range(20):
        try:
            page_elem = click_next_page(browser, current_page)
            print('Clicked page %s' % (current_page + 1))
            break
        except:
            print('Failed to click page %s' % (current_page + 1))
            time.sleep(1)
            continue
            
        

    # If the end of pages is reached
    if page_elem is None or page_cnt == num_pages:    
        break

    # Flip to next page
    current_page += 1
# Out:
# Processed page: 1!
# Clicked page 2
# Processed page: 2!
# Clicked page 3
# Processed page: 3!
# Clicked page 4
# Processed page: 4!
# Clicked page 5
# Failed to process problems on page 5
# Processed page: 5!
# Clicked page 6
# Processed page: 6!
# Clicked page 7
# Processed page: 7!
# Clicked page 8
# Failed to process problems on page 8
# Processed page: 8!
# Clicked page 9
# Processed page: 9!
# Clicked page 10
# Processed page: 10!
# Clicked page 11

# %%
import json

# Serialize data into file:
with open('rawproblems1.json', 'w') as fp:
    json.dump(problems_dict, fp)

# Read data from file:
with open('rawproblems1.json', 'r') as fp:
    problems_dict = json.load(fp)

# %% [markdown]
# ## 3. Visit each problem url and extract holds used in each problem.

# %%
uids = sorted(problems_dict.keys())

# Iterate through each problem
for i, uid in enumerate(uids):
    print(str(i + 1) + ' / ' + str(len(uids)))
    tmp_problem = copy.deepcopy(problems_dict[uid])
    
    browser.get(tmp_problem['url'])  # Navigate to page

    for x in range(10):
        try:
            target_text = ''
            html = browser.page_source
            soup = BeautifulSoup(html, 'html.parser')
            scripts = soup.find_all("script")
            for s in scripts:
                if 'JSON' in s.text:
                    target_text =  s.text

            json_dict = json.loads(target_text.split("var problem = JSON.parse('")[1].split("');")[0])
            tmp_problem['moves'] = json_dict['Moves']
                          
        except:
            print('Failed to find moves')
            time.sleep(1)
            continue

    
    problems_dict[uid] = tmp_problem
# Out:
# 1 / 61
# 2 / 61
# 3 / 61
# 4 / 61
# 5 / 61
# 6 / 61
# 7 / 61
# 8 / 61
# 9 / 61
# 10 / 61
# 11 / 61
# 12 / 61
# 13 / 61
# 14 / 61
# 15 / 61
# 16 / 61
# 17 / 61
# 18 / 61
# 19 / 61
# 20 / 61
# 21 / 61
# 22 / 61
# 23 / 61
# 24 / 61
# 25 / 61
# 26 / 61
# 27 / 61
# 28 / 61
# 29 / 61
# 30 / 61
# 31 / 61
# 32 / 61
# 33 / 61
# 34 / 61
# 35 / 61
# 36 / 61
# 37 / 61
# 38 / 61
# 39 / 61
# 40 / 61
# 41 / 61
# 42 / 61
# 43 / 61
# 44 / 61
# 45 / 61
# 46 / 61
# 47 / 61
# 48 / 61
# 49 / 61
# 50 / 61
# 51 / 61
# 52 / 61
# 53 / 61
# 54 / 61
# 55 / 61
# 56 / 61
# 57 / 61
# 58 / 61
# 59 / 61
# 60 / 61
# 61 / 61

# %%
problems_dict
# Out:
# {'372426': {'problem_name': 'KRAFTIS 1.1',
#   'info': ['Kimi',
#    'Be the first to repeat this problem',
#    '6A',
#    'Feet follow hands',
#    '25° MoonBoard'],
#   'url': 'https://moonboard.com/Problems/View/372426/kraftis-1-1',
#   'moves': [{'Id': 2154996,
#     'Description': 'I4',
#     'IsStart': True,
#     'IsEnd': False},
#    {'Id': 2154997, 'Description': 'F6', 'IsStart': True, 'IsEnd': False},
#    {'Id': 2154998, 'Description': 'J9', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2154999, 'Description': 'H11', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2155000, 'Description': 'I15', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2155001, 'Description': 'K17', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2155002, 'Description': 'K13', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2155003, 'Description': 'J18', 'IsStart': False, 'IsEnd': True}]},
#  '372424': {'problem_name': 'JOELQUISGAIS',
#   'info': ['Sergio jimenez del rio',
#    'Be the first to repeat this problem',
#    '6B',
#    'Feet follow hands',
#    '40° MoonBoard'],
#   'url': 'https://moonboard.com/Problems/View/372424/joelquisgais',
#   'moves': [{'Id': 2154979,
#     'Description': 'H5',
#     'IsStart': True,
#     'IsEnd': False},
#    {'Id': 2154980, 'Description': 'D9', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2154981, 'Description': 'A11', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2154982, 'Description': 'A6', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2154983, 'Description': 'E14', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2154984, 'Description': 'C14', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2154985, 'Description': 'F18', 'IsStart': False, 'IsEnd': True}]},
#  '372422': {'problem_name': 'LETNI MRDANI',
#   'info': ['knapa',
#    'Be the first to repeat this problem',
#    '6C+',
#    'Feet follow hands + screw ons',
#    '40° MoonBoard'],
#   'url': 'https://moonboard.com/Problems/View/372422/letni-mrdani',
#   'moves': [{'Id': 2154964,
#     'Description': 'E3',
#     'IsStart': True,
#     'IsEnd': False},
#    {'Id': 2154965, 'Description': 'I3', 'IsStart': True, 'IsEnd': False},
#    {'Id': 2154966, 'Description': 'F8', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2154967, 'Description': 'G10', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2154968, 'Description': 'D12', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2154969, 'Description': 'E14', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2154970, 'Description': 'D17', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2154971, 'Description': 'H18', 'IsStart': False, 'IsEnd': True}]},
#  '372421': {'problem_name': 'VYSOUNUV',
#   'info': ['knapa',
#    'Be the first to repeat this problem',
#    '6C+',
#    'Feet follow hands + screw ons',
#    '40° MoonBoard'],
#   'url': 'https://moonboard.com/Problems/View/372421/vysounuv',
#   'moves': [{'Id': 2154956,
#     'Description': 'E4',
#     'IsStart': True,
#     'IsEnd': False},
#    {'Id': 2154957, 'Description': 'F4', 'IsStart': True, 'IsEnd': False},
#    {'Id': 2154958, 'Description': 'I7', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2154959, 'Description': 'G11', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2154960, 'Description': 'F12', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2154961, 'Description': 'C15', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2154962, 'Description': 'E18', 'IsStart': False, 'IsEnd': True},
#    {'Id': 2154963, 'Description': 'G15', 'IsStart': False, 'IsEnd': False}]},
#  '372420': {'problem_name': 'BILDUNGSLÜCKE',
#   'info': ['Benev',
#    'Be the first to repeat this problem',
#    '6C+',
#    'Feet follow hands',
#    '40° MoonBoard'],
#   'url': 'https://moonboard.com/Problems/View/372420/bildungsl%C3%BCcke',
#   'moves': [{'Id': 2154948,
#     'Description': 'G4',
#     'IsStart': True,
#     'IsEnd': False},
#    {'Id': 2154949, 'Description': 'J6', 'IsStart': True, 'IsEnd': False},
#    {'Id': 2154950, 'Description': 'H9', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2154951, 'Description': 'G10', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2154952, 'Description': 'D12', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2154953, 'Description': 'C13', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2154954, 'Description': 'H15', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2154955, 'Description': 'F18', 'IsStart': False, 'IsEnd': True}]},
#  '372418': {'problem_name': 'BACKMISCHUNG',
#   'info': ['Surya Jarausch',
#    '1 climber has repeated this problem',
#    '6B',
#    'Feet follow hands',
#    '40° MoonBoard'],
#   'url': 'https://moonboard.com/Problems/View/372418/backmischung',
#   'moves': [{'Id': 2154933,
#     'Description': 'F5',
#     'IsStart': True,
#     'IsEnd': False},
#    {'Id': 2154934, 'Description': 'G8', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2154935, 'Description': 'G10', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2154936, 'Description': 'C10', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2154937, 'Description': 'B4', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2154938, 'Description': 'I2', 'IsStart': True, 'IsEnd': False},
#    {'Id': 2154939, 'Description': 'E14', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2154940, 'Description': 'D15', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2154941, 'Description': 'D18', 'IsStart': False, 'IsEnd': True}]},
#  '372415': {'problem_name': 'OHRENKERZE',
#   'info': ['Benev',
#    'Be the first to repeat this problem',
#    '6B+',
#    'Feet follow hands',
#    '40° MoonBoard'],
#   'url': 'https://moonboard.com/Problems/View/372415/ohrenkerze',
#   'moves': [{'Id': 2154909,
#     'Description': 'G4',
#     'IsStart': True,
#     'IsEnd': False},
#    {'Id': 2154910, 'Description': 'I2', 'IsStart': True, 'IsEnd': False},
#    {'Id': 2154911, 'Description': 'E6', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2154912, 'Description': 'G8', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2154913, 'Description': 'G10', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2154914, 'Description': 'D12', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2154915, 'Description': 'D15', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2154916, 'Description': 'D17', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2154917, 'Description': 'H18', 'IsStart': False, 'IsEnd': True}]},
#  '372399': {'problem_name': 'ヒ',
#   'info': ['sora',
#    'Be the first to repeat this problem',
#    '6B',
#    'Feet follow hands',
#    '40° MoonBoard'],
#   'url': 'https://moonboard.com/Problems/View/372399/%E3%83%92',
#   'moves': [{'Id': 2154776,
#     'Description': 'C18',
#     'IsStart': False,
#     'IsEnd': True},
#    {'Id': 2154777, 'Description': 'C15', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2154778, 'Description': 'C12', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2154779, 'Description': 'C10', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2154780, 'Description': 'C7', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2154781, 'Description': 'E12', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2154782, 'Description': 'F12', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2154783, 'Description': 'H12', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2154784, 'Description': 'C5', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2154785, 'Description': 'J12', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2154786, 'Description': 'C3', 'IsStart': True, 'IsEnd': False},
#    {'Id': 2154787, 'Description': 'I3', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2154788, 'Description': 'F3', 'IsStart': True, 'IsEnd': False},
#    {'Id': 2154789, 'Description': 'J3', 'IsStart': False, 'IsEnd': False}]},
#  '372398': {'problem_name': 'そ',
#   'info': ['sora',
#    'Be the first to repeat this problem',
#    '6B',
#    'Feet follow hands',
#    '40° MoonBoard'],
#   'url': 'https://moonboard.com/Problems/View/372398/%E3%81%9D',
#   'moves': [{'Id': 2154762,
#     'Description': 'G2',
#     'IsStart': True,
#     'IsEnd': False},
#    {'Id': 2154763, 'Description': 'D3', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2154764, 'Description': 'C5', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2154765, 'Description': 'C7', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2154766, 'Description': 'G11', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2154767, 'Description': 'H17', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2154768, 'Description': 'F15', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2154769, 'Description': 'B12', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2154770, 'Description': 'I12', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2154771, 'Description': 'F12', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2154772, 'Description': 'D14', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2154773, 'Description': 'E9', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2154774, 'Description': 'D12', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2154775, 'Description': 'C18', 'IsStart': False, 'IsEnd': True}]},
#  '372397': {'problem_name': '梅雨の晴れ間に',
#   'info': ['sora',
#    'Be the first to repeat this problem',
#    '8B+',
#    'Feet follow hands',
#    '40° MoonBoard'],
#   'url': 'https://moonboard.com/Problems/View/372397/%E6%A2%85%E9%9B%A8%E3%81%AE%E6%99%B4%E3%82%8C%E9%96%93%E3%81%AB',
#   'moves': [{'Id': 2154750,
#     'Description': 'B3',
#     'IsStart': True,
#     'IsEnd': False},
#    {'Id': 2154751, 'Description': 'A5', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2154752, 'Description': 'F5', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2154753, 'Description': 'F2', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2154754, 'Description': 'D9', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2154755, 'Description': 'E11', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2154756, 'Description': 'H7', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2154757, 'Description': 'B13', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2154758, 'Description': 'F15', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2154759, 'Description': 'I11', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2154760, 'Description': 'I12', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2154761, 'Description': 'H18', 'IsStart': False, 'IsEnd': True}]},
#  '372395': {'problem_name': 'AO',
#   'info': ['sora',
#    'Be the first to repeat this problem',
#    '6A+',
#    'Feet follow hands',
#    '40° MoonBoard'],
#   'url': 'https://moonboard.com/Problems/View/372395/ao',
#   'moves': [{'Id': 2154727,
#     'Description': 'D2',
#     'IsStart': True,
#     'IsEnd': False},
#    {'Id': 2154728, 'Description': 'G2', 'IsStart': True, 'IsEnd': False},
#    {'Id': 2154729, 'Description': 'D4', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2154730, 'Description': 'F5', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2154731, 'Description': 'F6', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2154732, 'Description': 'G8', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2154733, 'Description': 'D8', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2154734, 'Description': 'F9', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2154735, 'Description': 'D11', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2154736, 'Description': 'F11', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2154737, 'Description': 'E13', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2154738, 'Description': 'C14', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2154739, 'Description': 'A14', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2154740, 'Description': 'B18', 'IsStart': False, 'IsEnd': True}]},
#  '372394': {'problem_name': 'ジャンケン5',
#   'info': ['yoshiton',
#    'Be the first to repeat this problem',
#    '6B+',
#    'Feet follow hands',
#    '40° MoonBoard'],
#   'url': 'https://moonboard.com/Problems/View/372394/%E3%82%B8%E3%83%A3%E3%83%B3%E3%82%B1%E3%83%B35',
#   'moves': [{'Id': 2154720,
#     'Description': 'F4',
#     'IsStart': True,
#     'IsEnd': False},
#    {'Id': 2154721, 'Description': 'C7', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2154722, 'Description': 'F10', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2154723, 'Description': 'D13', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2154724, 'Description': 'E14', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2154725, 'Description': 'C17', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2154726, 'Description': 'F18', 'IsStart': False, 'IsEnd': True}]},
#  '372393': {'problem_name': 'ジャンケン4',
#   'info': ['yoshiton',
#    'Be the first to repeat this problem',
#    '6B',
#    'Feet follow hands',
#    '40° MoonBoard'],
#   'url': 'https://moonboard.com/Problems/View/372393/%E3%82%B8%E3%83%A3%E3%83%B3%E3%82%B1%E3%83%B34',
#   'moves': [{'Id': 2154714,
#     'Description': 'B3',
#     'IsStart': True,
#     'IsEnd': False},
#    {'Id': 2154715, 'Description': 'E7', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2154716, 'Description': 'D10', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2154717, 'Description': 'F13', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2154718, 'Description': 'C15', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2154719, 'Description': 'D18', 'IsStart': False, 'IsEnd': True}]},
#  '372392': {'problem_name': 'ジャンケン3',
#   'info': ['yoshiton',
#    'Be the first to repeat this problem',
#    '6B',
#    'Feet follow hands',
#    '40° MoonBoard'],
#   'url': 'https://moonboard.com/Problems/View/372392/%E3%82%B8%E3%83%A3%E3%83%B3%E3%82%B1%E3%83%B33',
#   'moves': [{'Id': 2154708,
#     'Description': 'H5',
#     'IsStart': True,
#     'IsEnd': False},
#    {'Id': 2154709, 'Description': 'E3', 'IsStart': True, 'IsEnd': False},
#    {'Id': 2154710, 'Description': 'D9', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2154711, 'Description': 'E13', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2154712, 'Description': 'E17', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2154713, 'Description': 'E18', 'IsStart': False, 'IsEnd': True}]},
#  '372391': {'problem_name': 'ジャンケン2',
#   'info': ['yoshiton',
#    'Be the first to repeat this problem',
#    '6B',
#    'Feet follow hands',
#    '40° MoonBoard'],
#   'url': 'https://moonboard.com/Problems/View/372391/%E3%82%B8%E3%83%A3%E3%83%B3%E3%82%B1%E3%83%B32',
#   'moves': [{'Id': 2154703,
#     'Description': 'F5',
#     'IsStart': True,
#     'IsEnd': False},
#    {'Id': 2154704, 'Description': 'F9', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2154705, 'Description': 'G13', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2154706, 'Description': 'E15', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2154707, 'Description': 'E18', 'IsStart': False, 'IsEnd': True}]},
#  '372330': {'problem_name': 'DANG WARM UP',
#   'info': ['Alfred',
#    'Be the first to repeat this problem',
#    '6A+',
#    'Footless + kickboard',
#    '40° MoonBoard'],
#   'url': 'https://moonboard.com/Problems/View/372330/dang-warm-up',
#   'moves': [{'Id': 2154263,
#     'Description': 'F5',
#     'IsStart': True,
#     'IsEnd': False},
#    {'Id': 2154264, 'Description': 'B8', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2154265, 'Description': 'C10', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2154266, 'Description': 'B13', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2154267, 'Description': 'F15', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2154268, 'Description': 'C16', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2154269, 'Description': 'F18', 'IsStart': False, 'IsEnd': True}]},
#  '372329': {'problem_name': 'MID LANE',
#   'info': ['Joshua',
#    'Be the first to repeat this problem',
#    '7A+',
#    'Feet follow hands',
#    '40° MoonBoard'],
#   'url': 'https://moonboard.com/Problems/View/372329/mid-lane',
#   'moves': [{'Id': 2154255,
#     'Description': 'H3',
#     'IsStart': True,
#     'IsEnd': False},
#    {'Id': 2154256, 'Description': 'E3', 'IsStart': True, 'IsEnd': False},
#    {'Id': 2154257, 'Description': 'E7', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2154258, 'Description': 'H7', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2154259, 'Description': 'G10', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2154260, 'Description': 'D13', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2154261, 'Description': 'H14', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2154262, 'Description': 'F18', 'IsStart': False, 'IsEnd': True}]},
#  '372328': {'problem_name': 'BOT LANE',
#   'info': ['Joshua',
#    'Be the first to repeat this problem',
#    '7B+',
#    'Feet follow hands',
#    '40° MoonBoard'],
#   'url': 'https://moonboard.com/Problems/View/372328/bot-lane',
#   'moves': [{'Id': 2154248,
#     'Description': 'H5',
#     'IsStart': True,
#     'IsEnd': False},
#    {'Id': 2154249, 'Description': 'I4', 'IsStart': True, 'IsEnd': False},
#    {'Id': 2154250, 'Description': 'K10', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2154251, 'Description': 'K2', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2154252, 'Description': 'J13', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2154253, 'Description': 'J18', 'IsStart': False, 'IsEnd': True},
#    {'Id': 2154254, 'Description': 'K16', 'IsStart': False, 'IsEnd': False}]},
#  '372327': {'problem_name': 'TOP LANE',
#   'info': ['Joshua',
#    'Be the first to repeat this problem',
#    '7B+',
#    'Feet follow hands',
#    '40° MoonBoard'],
#   'url': 'https://moonboard.com/Problems/View/372327/top-lane',
#   'moves': [{'Id': 2154239,
#     'Description': 'D4',
#     'IsStart': True,
#     'IsEnd': False},
#    {'Id': 2154240, 'Description': 'D5', 'IsStart': True, 'IsEnd': False},
#    {'Id': 2154241, 'Description': 'A3', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2154242, 'Description': 'A2', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2154243, 'Description': 'A10', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2154244, 'Description': 'A12', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2154245, 'Description': 'B15', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2154246, 'Description': 'E1', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2154247, 'Description': 'A18', 'IsStart': False, 'IsEnd': True}]},
#  '372326': {'problem_name': 'NEEKO TRANSFORM!',
#   'info': ['Joshua',
#    'Be the first to repeat this problem',
#    '7C',
#    'Feet follow hands',
#    '40° MoonBoard'],
#   'url': 'https://moonboard.com/Problems/View/372326/neeko-transform',
#   'moves': [{'Id': 2154232,
#     'Description': 'C6',
#     'IsStart': True,
#     'IsEnd': False},
#    {'Id': 2154233, 'Description': 'D3', 'IsStart': True, 'IsEnd': False},
#    {'Id': 2154234, 'Description': 'H8', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2154235, 'Description': 'H12', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2154236, 'Description': 'I13', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2154237, 'Description': 'E16', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2154238, 'Description': 'I18', 'IsStart': False, 'IsEnd': True}]},
#  '372304': {'problem_name': 'RED MANIAC V2',
#   'info': ['Artiom_Levitchii',
#    'Be the first to repeat this problem',
#    '6B',
#    'Feet follow hands',
#    '25° MoonBoard'],
#   'url': 'https://moonboard.com/Problems/View/372304/red-maniac-v2',
#   'moves': [{'Id': 2154070,
#     'Description': 'A4',
#     'IsStart': True,
#     'IsEnd': False},
#    {'Id': 2154071, 'Description': 'E7', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2154072, 'Description': 'H8', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2154073, 'Description': 'H12', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2154074, 'Description': 'J14', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2154075, 'Description': 'F17', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2154076, 'Description': 'B18', 'IsStart': False, 'IsEnd': True}]},
#  '372301': {'problem_name': 'FEELING JUMPY',
#   'info': ['gogo',
#    '3 climbers have repeated this problem',
#    '6B',
#    'Feet follow hands',
#    '40° MoonBoard'],
#   'url': 'https://moonboard.com/Problems/View/372301/feeling-jumpy',
#   'moves': [{'Id': 2154053,
#     'Description': 'G6',
#     'IsStart': True,
#     'IsEnd': False},
#    {'Id': 2154054, 'Description': 'J4', 'IsStart': True, 'IsEnd': False},
#    {'Id': 2154055, 'Description': 'H10', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2154056, 'Description': 'E13', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2154057, 'Description': 'D18', 'IsStart': False, 'IsEnd': True}]},
#  '372295': {'problem_name': 'BABY TIME',
#   'info': ['shirlich',
#    'Be the first to repeat this problem',
#    '6B',
#    'Feet follow hands',
#    '40° MoonBoard'],
#   'url': 'https://moonboard.com/Problems/View/372295/baby-time',
#   'moves': [{'Id': 2154006,
#     'Description': 'I3',
#     'IsStart': True,
#     'IsEnd': False},
#    {'Id': 2154007, 'Description': 'J6', 'IsStart': True, 'IsEnd': False},
#    {'Id': 2154008, 'Description': 'J3', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2154009, 'Description': 'F2', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2154010, 'Description': 'F10', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2154011, 'Description': 'G13', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2154012, 'Description': 'E15', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2154013, 'Description': 'G17', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2154014, 'Description': 'H18', 'IsStart': False, 'IsEnd': True},
#    {'Id': 2154015, 'Description': 'I8', 'IsStart': False, 'IsEnd': False}]},
#  '372294': {'problem_name': 'BIG JUMP',
#   'info': ['puga.climbing',
#    '4 climbers have repeated this problem',
#    '6C+',
#    'Feet follow hands',
#    '40° MoonBoard'],
#   'url': 'https://moonboard.com/Problems/View/372294/big-jump',
#   'moves': [{'Id': 2154000,
#     'Description': 'F6',
#     'IsStart': True,
#     'IsEnd': False},
#    {'Id': 2154001, 'Description': 'I3', 'IsStart': True, 'IsEnd': False},
#    {'Id': 2154002, 'Description': 'H8', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2154003, 'Description': 'E7', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2154004, 'Description': 'E13', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2154005, 'Description': 'F18', 'IsStart': False, 'IsEnd': True}]},
#  '372291': {'problem_name': 'HIKASOYO',
#   'info': ['shinji1104',
#    '1 climber has repeated this problem',
#    '6B',
#    'Feet follow hands',
#    '40° MoonBoard'],
#   'url': 'https://moonboard.com/Problems/View/372291/hikasoyo',
#   'moves': [{'Id': 2153971,
#     'Description': 'H5',
#     'IsStart': True,
#     'IsEnd': False},
#    {'Id': 2153972, 'Description': 'G7', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2153973, 'Description': 'D10', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2153974, 'Description': 'G13', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2153975, 'Description': 'H2', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2153976, 'Description': 'C5', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2153977, 'Description': 'K11', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2153978, 'Description': 'J15', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2153979, 'Description': 'G17', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2153980, 'Description': 'F18', 'IsStart': False, 'IsEnd': True},
#    {'Id': 2153981, 'Description': 'E6', 'IsStart': False, 'IsEnd': False}]},
#  '372289': {'problem_name': 'ROJO',
#   'info': ['Carles march',
#    '3 climbers have repeated this problem',
#    '6A+',
#    'Feet follow hands',
#    '40° MoonBoard'],
#   'url': 'https://moonboard.com/Problems/View/372289/rojo',
#   'moves': [{'Id': 2153956,
#     'Description': 'F5',
#     'IsStart': True,
#     'IsEnd': False},
#    {'Id': 2153957, 'Description': 'H5', 'IsStart': True, 'IsEnd': False},
#    {'Id': 2153958, 'Description': 'F8', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2153959, 'Description': 'J11', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2153960, 'Description': 'G11', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2153961, 'Description': 'K14', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2153962, 'Description': 'I16', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2153963, 'Description': 'J18', 'IsStart': False, 'IsEnd': True}]},
#  '372288': {'problem_name': 'NO GAIN',
#   'info': ['Fondei',
#    '1 climber has repeated this problem',
#    '6A+',
#    'Feet follow hands',
#    '40° MoonBoard'],
#   'url': 'https://moonboard.com/Problems/View/372288/no-gain',
#   'moves': [{'Id': 2153951,
#     'Description': 'F5',
#     'IsStart': True,
#     'IsEnd': False},
#    {'Id': 2153952, 'Description': 'J7', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2153953, 'Description': 'H10', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2153954, 'Description': 'K13', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2153955, 'Description': 'H18', 'IsStart': False, 'IsEnd': True}]},
#  '372287': {'problem_name': 'NO PAIN',
#   'info': ['Fondei',
#    '1 climber has repeated this problem',
#    '6A+',
#    'Feet follow hands',
#    '40° MoonBoard'],
#   'url': 'https://moonboard.com/Problems/View/372287/no-pain',
#   'moves': [{'Id': 2153945,
#     'Description': 'F5',
#     'IsStart': True,
#     'IsEnd': False},
#    {'Id': 2153946, 'Description': 'I8', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2153947, 'Description': 'H10', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2153948, 'Description': 'C13', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2153949, 'Description': 'G14', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2153950, 'Description': 'H18', 'IsStart': False, 'IsEnd': True}]},
#  '372281': {'problem_name': 'GASTON OR PINCH',
#   'info': ['Justin Menestrina',
#    '4 climbers have repeated this problem',
#    '6C+',
#    'Feet follow hands',
#    '40° MoonBoard'],
#   'url': 'https://moonboard.com/Problems/View/372281/gaston-or-pinch',
#   'moves': [{'Id': 2153901,
#     'Description': 'A6',
#     'IsStart': True,
#     'IsEnd': False},
#    {'Id': 2153902, 'Description': 'E3', 'IsStart': True, 'IsEnd': False},
#    {'Id': 2153903, 'Description': 'A4', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2153904, 'Description': 'D2', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2153905, 'Description': 'F8', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2153906, 'Description': 'B11', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2153907, 'Description': 'G11', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2153908, 'Description': 'E17', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2153909, 'Description': 'E18', 'IsStart': False, 'IsEnd': True},
#    {'Id': 2153910, 'Description': 'C14', 'IsStart': False, 'IsEnd': False}]},
#  '372276': {'problem_name': "WOODY'S FIRST PROBLEM",
#   'info': ['Justin Menestrina',
#    'Be the first to repeat this problem',
#    '6C+',
#    'Feet follow hands',
#    '40° MoonBoard'],
#   'url': 'https://moonboard.com/Problems/View/372276/woody-s-first-problem',
#   'moves': [{'Id': 2153864,
#     'Description': 'H5',
#     'IsStart': True,
#     'IsEnd': False},
#    {'Id': 2153865, 'Description': 'F6', 'IsStart': True, 'IsEnd': False},
#    {'Id': 2153866, 'Description': 'J9', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2153867, 'Description': 'G11', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2153868, 'Description': 'F15', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2153869, 'Description': 'C12', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2153870, 'Description': 'B18', 'IsStart': False, 'IsEnd': True}]},
#  '372272': {'problem_name': 'JIVE DUDE',
#   'info': ['Jeremy Tibbals',
#    '2 climbers have repeated this problem',
#    '6C+',
#    'Feet follow hands',
#    '40° MoonBoard'],
#   'url': 'https://moonboard.com/Problems/View/372272/jive-dude',
#   'moves': [{'Id': 2153830,
#     'Description': 'G3',
#     'IsStart': True,
#     'IsEnd': False},
#    {'Id': 2153831, 'Description': 'I3', 'IsStart': True, 'IsEnd': False},
#    {'Id': 2153832, 'Description': 'F7', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2153833, 'Description': 'E8', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2153834, 'Description': 'B9', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2153835, 'Description': 'A11', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2153836, 'Description': 'D15', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2153837, 'Description': 'F15', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2153838, 'Description': 'F17', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2153839, 'Description': 'H18', 'IsStart': False, 'IsEnd': True},
#    {'Id': 2153840, 'Description': 'J10', 'IsStart': False, 'IsEnd': False}]},
#  '372270': {'problem_name': 'FÜR BINDI',
#   'info': ['Cole Verrall',
#    'Be the first to repeat this problem',
#    '6A+',
#    'Feet follow hands',
#    '25° MoonBoard'],
#   'url': 'https://moonboard.com/Problems/View/372270/f%C3%BCr-bindi',
#   'moves': [{'Id': 2153814,
#     'Description': 'D1',
#     'IsStart': True,
#     'IsEnd': False},
#    {'Id': 2153815, 'Description': 'I4', 'IsStart': True, 'IsEnd': False},
#    {'Id': 2153816, 'Description': 'G8', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2153817, 'Description': 'D10', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2153818, 'Description': 'A8', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2153819, 'Description': 'H14', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2153820, 'Description': 'F14', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2153821, 'Description': 'H18', 'IsStart': False, 'IsEnd': True}]},
#  '372269': {'problem_name': 'TEST1.8.8',
#   'info': ['koma',
#    '1 climber has repeated this problem',
#    '6C',
#    'Feet follow hands',
#    '40° MoonBoard'],
#   'url': 'https://moonboard.com/Problems/View/372269/test1-8-8',
#   'moves': [{'Id': 2153807,
#     'Description': 'C5',
#     'IsStart': True,
#     'IsEnd': False},
#    {'Id': 2153808, 'Description': 'F5', 'IsStart': True, 'IsEnd': False},
#    {'Id': 2153809, 'Description': 'C8', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2153810, 'Description': 'G11', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2153811, 'Description': 'D14', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2153812, 'Description': 'E14', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2153813, 'Description': 'F18', 'IsStart': False, 'IsEnd': True}]},
#  '372264': {'problem_name': 'SE*Y URBY',
#   'info': ['mattia_besso',
#    'Be the first to repeat this problem',
#    '7B',
#    'Feet follow hands',
#    '25° MoonBoard'],
#   'url': 'https://moonboard.com/Problems/View/372264/se-y-urby',
#   'moves': [{'Id': 2153776,
#     'Description': 'A6',
#     'IsStart': True,
#     'IsEnd': False},
#    {'Id': 2153777, 'Description': 'E4', 'IsStart': True, 'IsEnd': False},
#    {'Id': 2153778, 'Description': 'I10', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2153779, 'Description': 'G11', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2153780, 'Description': 'E14', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2153781, 'Description': 'F16', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2153782, 'Description': 'K18', 'IsStart': False, 'IsEnd': True}]},
#  '372263': {'problem_name': 'POUR LES GROSSES MERDES',
#   'info': ['Loulou',
#    '9 climbers have repeated this problem',
#    '6A+',
#    'Feet follow hands',
#    '40° MoonBoard'],
#   'url': 'https://moonboard.com/Problems/View/372263/pour-les-grosses-merdes',
#   'moves': [{'Id': 2153765,
#     'Description': 'H5',
#     'IsStart': True,
#     'IsEnd': False},
#    {'Id': 2153766, 'Description': 'F5', 'IsStart': True, 'IsEnd': False},
#    {'Id': 2153767, 'Description': 'K1', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2153768, 'Description': 'I8', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2153769, 'Description': 'H10', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2153770, 'Description': 'J13', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2153771, 'Description': 'E13', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2153772, 'Description': 'E14', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2153773, 'Description': 'C16', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2153774, 'Description': 'F18', 'IsStart': False, 'IsEnd': True},
#    {'Id': 2153775, 'Description': 'F11', 'IsStart': False, 'IsEnd': False}]},
#  '372262': {'problem_name': 'ROCKTOPIEN 4',
#   'info': ['Loulou',
#    '2 climbers have repeated this problem',
#    '6C+',
#    'Feet follow hands',
#    '40° MoonBoard'],
#   'url': 'https://moonboard.com/Problems/View/372262/rocktopien-4',
#   'moves': [{'Id': 2153754,
#     'Description': 'G6',
#     'IsStart': True,
#     'IsEnd': False},
#    {'Id': 2153755, 'Description': 'D9', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2153756, 'Description': 'F11', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2153757, 'Description': 'C12', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2153758, 'Description': 'K3', 'IsStart': True, 'IsEnd': False},
#    {'Id': 2153759, 'Description': 'G8', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2153760, 'Description': 'C3', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2153761, 'Description': 'B7', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2153762, 'Description': 'H14', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2153763, 'Description': 'H18', 'IsStart': False, 'IsEnd': True},
#    {'Id': 2153764, 'Description': 'F16', 'IsStart': False, 'IsEnd': False}]},
#  '372261': {'problem_name': 'ROCKTOPIEN 3',
#   'info': ['Loulou',
#    '2 climbers have repeated this problem',
#    '6C+',
#    'Feet follow hands',
#    '40° MoonBoard'],
#   'url': 'https://moonboard.com/Problems/View/372261/rocktopien-3',
#   'moves': [{'Id': 2153745,
#     'Description': 'K6',
#     'IsStart': True,
#     'IsEnd': False},
#    {'Id': 2153746, 'Description': 'K5', 'IsStart': True, 'IsEnd': False},
#    {'Id': 2153747, 'Description': 'K9', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2153748, 'Description': 'G3', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2153749, 'Description': 'F10', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2153750, 'Description': 'G13', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2153751, 'Description': 'F16', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2153752, 'Description': 'G18', 'IsStart': False, 'IsEnd': True},
#    {'Id': 2153753, 'Description': 'F7', 'IsStart': False, 'IsEnd': False}]},
#  '372258': {'problem_name': 'KÖMAU - MAZE GOES HARD',
#   'info': ['Thomas',
#    '2 climbers have repeated this problem',
#    '6B+',
#    'Feet follow hands',
#    '40° MoonBoard'],
#   'url': 'https://moonboard.com/Problems/View/372258/k%C3%B6mau-maze-goes-hard',
#   'moves': [{'Id': 2153721,
#     'Description': 'F5',
#     'IsStart': True,
#     'IsEnd': False},
#    {'Id': 2153722, 'Description': 'J2', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2153723, 'Description': 'G7', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2153724, 'Description': 'F3', 'IsStart': True, 'IsEnd': False},
#    {'Id': 2153725, 'Description': 'D10', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2153726, 'Description': 'G13', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2153727, 'Description': 'C15', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2153728, 'Description': 'F18', 'IsStart': False, 'IsEnd': True}]},
#  '372257': {'problem_name': 'LOS BTR DEL CUEVACHO',
#   'info': ['david',
#    '2 climbers have repeated this problem',
#    '7A',
#    'Feet follow hands',
#    '40° MoonBoard'],
#   'url': 'https://moonboard.com/Problems/View/372257/los-btr-del-cuevacho',
#   'moves': [{'Id': 2153714,
#     'Description': 'J5',
#     'IsStart': True,
#     'IsEnd': False},
#    {'Id': 2153715, 'Description': 'G6', 'IsStart': True, 'IsEnd': False},
#    {'Id': 2153716, 'Description': 'I9', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2153717, 'Description': 'F10', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2153718, 'Description': 'F14', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2153719, 'Description': 'D16', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2153720, 'Description': 'H18', 'IsStart': False, 'IsEnd': True}]},
#  '372256': {'problem_name': 'DELTA LINE',
#   'info': ['puga.climbing',
#    'Be the first to repeat this problem',
#    '7A',
#    'Feet follow hands',
#    '40° MoonBoard'],
#   'url': 'https://moonboard.com/Problems/View/372256/delta-line',
#   'moves': [{'Id': 2153708,
#     'Description': 'H5',
#     'IsStart': True,
#     'IsEnd': False},
#    {'Id': 2153709, 'Description': 'H4', 'IsStart': True, 'IsEnd': False},
#    {'Id': 2153710, 'Description': 'D9', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2153711, 'Description': 'J11', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2153712, 'Description': 'G16', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2153713, 'Description': 'K18', 'IsStart': False, 'IsEnd': True}]},
#  '372255': {'problem_name': 'METAMORFO',
#   'info': ['puga.climbing',
#    '2 climbers have repeated this problem',
#    '6C+',
#    'Feet follow hands',
#    '40° MoonBoard'],
#   'url': 'https://moonboard.com/Problems/View/372255/metamorfo',
#   'moves': [{'Id': 2153701,
#     'Description': 'F4',
#     'IsStart': True,
#     'IsEnd': False},
#    {'Id': 2153702, 'Description': 'H1', 'IsStart': True, 'IsEnd': False},
#    {'Id': 2153703, 'Description': 'C7', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2153704, 'Description': 'E11', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2153705, 'Description': 'B13', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2153706, 'Description': 'A14', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2153707, 'Description': 'C18', 'IsStart': False, 'IsEnd': True}]},
#  '372253': {'problem_name': 'AQUALATA',
#   'info': ['Otsolà',
#    'Be the first to repeat this problem',
#    '6B+',
#    'Feet follow hands',
#    '40° MoonBoard'],
#   'url': 'https://moonboard.com/Problems/View/372253/aqualata',
#   'moves': [{'Id': 2153681,
#     'Description': 'F1',
#     'IsStart': True,
#     'IsEnd': False},
#    {'Id': 2153682, 'Description': 'H5', 'IsStart': True, 'IsEnd': False},
#    {'Id': 2153683, 'Description': 'E6', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2153684, 'Description': 'I8', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2153685, 'Description': 'K5', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2153686, 'Description': 'H11', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2153687, 'Description': 'I14', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2153688, 'Description': 'I15', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2153689, 'Description': 'F18', 'IsStart': False, 'IsEnd': True},
#    {'Id': 2153690, 'Description': 'H18', 'IsStart': False, 'IsEnd': True}]},
#  '372247': {'problem_name': 'LISL FUTZ',
#   'info': ['Andi',
#    '2 climbers have repeated this problem',
#    '6A+',
#    'Feet follow hands',
#    '40° MoonBoard'],
#   'url': 'https://moonboard.com/Problems/View/372247/lisl-futz',
#   'moves': [{'Id': 2153636,
#     'Description': 'D5',
#     'IsStart': True,
#     'IsEnd': False},
#    {'Id': 2153637, 'Description': 'F8', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2153638, 'Description': 'F9', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2153639, 'Description': 'J11', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2153640, 'Description': 'H14', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2153641, 'Description': 'H15', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2153642, 'Description': 'F18', 'IsStart': False, 'IsEnd': True}]},
#  '372234': {'problem_name': 'SPIGOLO DI GUGGI',
#   'info': ['guggy122',
#    '9 climbers have repeated this problem',
#    '6A+',
#    'Feet follow hands',
#    '40° MoonBoard'],
#   'url': 'https://moonboard.com/Problems/View/372234/spigolo-di-guggi',
#   'moves': [{'Id': 2153545,
#     'Description': 'F6',
#     'IsStart': True,
#     'IsEnd': False},
#    {'Id': 2153546, 'Description': 'H5', 'IsStart': True, 'IsEnd': False},
#    {'Id': 2153547, 'Description': 'H10', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2153548, 'Description': 'E13', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2153549, 'Description': 'G13', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2153550, 'Description': 'F18', 'IsStart': False, 'IsEnd': True},
#    {'Id': 2153551, 'Description': 'C7', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2153552, 'Description': 'K4', 'IsStart': False, 'IsEnd': False}]},
#  '372227': {'problem_name': 'DEMA ET DIC ALGO',
#   'info': ['wgc',
#    '1 climber has repeated this problem',
#    '6C+',
#    'Feet follow hands',
#    '40° MoonBoard'],
#   'url': 'https://moonboard.com/Problems/View/372227/dema-et-dic-algo',
#   'moves': [{'Id': 2153493,
#     'Description': 'E4',
#     'IsStart': True,
#     'IsEnd': False},
#    {'Id': 2153494, 'Description': 'G1', 'IsStart': True, 'IsEnd': False},
#    {'Id': 2153495, 'Description': 'F10', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2153496, 'Description': 'B7', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2153497, 'Description': 'C13', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2153498, 'Description': 'H16', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2153499, 'Description': 'E18', 'IsStart': False, 'IsEnd': True},
#    {'Id': 2153500, 'Description': 'J18', 'IsStart': False, 'IsEnd': True}]},
#  '372222': {'problem_name': 'EASY, EASIER, EASIEST 02',
#   'info': ['holger',
#    '7 climbers have repeated this problem',
#    '5+',
#    'Feet follow hands',
#    '25° MoonBoard'],
#   'url': 'https://moonboard.com/Problems/View/372222/easy-easier-easiest-02',
#   'moves': [{'Id': 2153443,
#     'Description': 'D5',
#     'IsStart': True,
#     'IsEnd': False},
#    {'Id': 2153444, 'Description': 'F5', 'IsStart': True, 'IsEnd': False},
#    {'Id': 2153445, 'Description': 'D9', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2153446, 'Description': 'D10', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2153447, 'Description': 'E13', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2153448, 'Description': 'A14', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2153449, 'Description': 'C16', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2153450, 'Description': 'B18', 'IsStart': False, 'IsEnd': True},
#    {'Id': 2153451, 'Description': 'F8', 'IsStart': False, 'IsEnd': False}]},
#  '372179': {'problem_name': 'DIOCANE',
#   'info': ['mikirasta',
#    '1 climber has repeated this problem',
#    '7A',
#    'Feet follow hands',
#    '40° MoonBoard'],
#   'url': 'https://moonboard.com/Problems/View/372179/diocane',
#   'moves': [{'Id': 2153056,
#     'Description': 'C4',
#     'IsStart': True,
#     'IsEnd': False},
#    {'Id': 2153057, 'Description': 'H2', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2153058, 'Description': 'F7', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2153059, 'Description': 'E9', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2153060, 'Description': 'I10', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2153061, 'Description': 'E13', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2153062, 'Description': 'H15', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2153063, 'Description': 'H17', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2153064, 'Description': 'J18', 'IsStart': False, 'IsEnd': True}]},
#  '372170': {'problem_name': 'MATTEO',
#   'info': ['Dado48',
#    'Be the first to repeat this problem',
#    '5+',
#    'Feet follow hands',
#    '25° MoonBoard'],
#   'url': 'https://moonboard.com/Problems/View/372170/matteo',
#   'moves': [{'Id': 2152986,
#     'Description': 'F4',
#     'IsStart': True,
#     'IsEnd': False},
#    {'Id': 2152987, 'Description': 'G4', 'IsStart': True, 'IsEnd': False},
#    {'Id': 2152988, 'Description': 'E6', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2152989, 'Description': 'E8', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2152990, 'Description': 'C10', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2152991, 'Description': 'E13', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2152992, 'Description': 'J13', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2152993, 'Description': 'I16', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2152994, 'Description': 'J18', 'IsStart': False, 'IsEnd': True},
#    {'Id': 2152995, 'Description': 'C2', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2152996, 'Description': 'I7', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2152997, 'Description': 'J10', 'IsStart': False, 'IsEnd': False}]},
#  '372169': {'problem_name': 'FRANCESCO',
#   'info': ['Dado48',
#    '6 climbers have repeated this problem',
#    '6A',
#    'Feet follow hands',
#    '25° MoonBoard'],
#   'url': 'https://moonboard.com/Problems/View/372169/francesco',
#   'moves': [{'Id': 2152976,
#     'Description': 'F6',
#     'IsStart': True,
#     'IsEnd': False},
#    {'Id': 2152977, 'Description': 'I3', 'IsStart': True, 'IsEnd': False},
#    {'Id': 2152978, 'Description': 'G8', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2152979, 'Description': 'D9', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2152980, 'Description': 'E11', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2152981, 'Description': 'C13', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2152982, 'Description': 'E16', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2152983, 'Description': 'E18', 'IsStart': False, 'IsEnd': True},
#    {'Id': 2152984, 'Description': 'C4', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2152985, 'Description': 'C3', 'IsStart': False, 'IsEnd': False}]},
#  '372168': {'problem_name': 'GIOVANNI',
#   'info': ['Dado48',
#    '2 climbers have repeated this problem',
#    '5+',
#    'Feet follow hands',
#    '25° MoonBoard'],
#   'url': 'https://moonboard.com/Problems/View/372168/giovanni',
#   'moves': [{'Id': 2152963,
#     'Description': 'H5',
#     'IsStart': True,
#     'IsEnd': False},
#    {'Id': 2152964, 'Description': 'I8', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2152965, 'Description': 'F9', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2152966, 'Description': 'G10', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2152967, 'Description': 'C10', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2152968, 'Description': 'G13', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2152969, 'Description': 'D15', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2152970, 'Description': 'D17', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2152971, 'Description': 'D18', 'IsStart': False, 'IsEnd': True},
#    {'Id': 2152972, 'Description': 'H2', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2152973, 'Description': 'C3', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2152974, 'Description': 'C5', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2152975, 'Description': 'B7', 'IsStart': False, 'IsEnd': False}]},
#  '372167': {'problem_name': 'MAX',
#   'info': ['Dado48',
#    '4 climbers have repeated this problem',
#    '5+',
#    'Feet follow hands',
#    '25° MoonBoard'],
#   'url': 'https://moonboard.com/Problems/View/372167/max',
#   'moves': [{'Id': 2152951,
#     'Description': 'E6',
#     'IsStart': True,
#     'IsEnd': False},
#    {'Id': 2152952, 'Description': 'A5', 'IsStart': True, 'IsEnd': False},
#    {'Id': 2152953, 'Description': 'D9', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2152954, 'Description': 'D10', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2152955, 'Description': 'B13', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2152956, 'Description': 'C13', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2152957, 'Description': 'D15', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2152958, 'Description': 'C16', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2152959, 'Description': 'F18', 'IsStart': False, 'IsEnd': True},
#    {'Id': 2152960, 'Description': 'D1', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2152961, 'Description': 'C2', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2152962, 'Description': 'C8', 'IsStart': False, 'IsEnd': False}]},
#  '372166': {'problem_name': 'GIUSEPPE',
#   'info': ['Dado48',
#    '3 climbers have repeated this problem',
#    '5+',
#    'Feet follow hands',
#    '25° MoonBoard'],
#   'url': 'https://moonboard.com/Problems/View/372166/giuseppe',
#   'moves': [{'Id': 2152939,
#     'Description': 'F5',
#     'IsStart': True,
#     'IsEnd': False},
#    {'Id': 2152940, 'Description': 'B3', 'IsStart': True, 'IsEnd': False},
#    {'Id': 2152941, 'Description': 'F8', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2152942, 'Description': 'J9', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2152943, 'Description': 'J11', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2152944, 'Description': 'G14', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2152945, 'Description': 'H15', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2152946, 'Description': 'E16', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2152947, 'Description': 'F18', 'IsStart': False, 'IsEnd': True},
#    {'Id': 2152948, 'Description': 'I3', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2152949, 'Description': 'J4', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2152950, 'Description': 'H6', 'IsStart': False, 'IsEnd': False}]},
#  '372165': {'problem_name': 'IRENE',
#   'info': ['Dado48',
#    '4 climbers have repeated this problem',
#    '5+',
#    'Feet follow hands',
#    '25° MoonBoard'],
#   'url': 'https://moonboard.com/Problems/View/372165/irene',
#   'moves': [{'Id': 2152927,
#     'Description': 'H5',
#     'IsStart': True,
#     'IsEnd': False},
#    {'Id': 2152928, 'Description': 'J4', 'IsStart': True, 'IsEnd': False},
#    {'Id': 2152929, 'Description': 'I7', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2152930, 'Description': 'F8', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2152931, 'Description': 'H10', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2152932, 'Description': 'F12', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2152933, 'Description': 'G13', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2152934, 'Description': 'C14', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2152935, 'Description': 'C16', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2152936, 'Description': 'B18', 'IsStart': False, 'IsEnd': True},
#    {'Id': 2152937, 'Description': 'J1', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2152938, 'Description': 'A9', 'IsStart': False, 'IsEnd': False}]},
#  '372164': {'problem_name': 'TCM',
#   'info': ['Charlène Tilborghs',
#    '2 climbers have repeated this problem',
#    '7A',
#    'Feet follow hands',
#    '40° MoonBoard'],
#   'url': 'https://moonboard.com/Problems/View/372164/tcm',
#   'moves': [{'Id': 2152920,
#     'Description': 'E4',
#     'IsStart': True,
#     'IsEnd': False},
#    {'Id': 2152921, 'Description': 'H3', 'IsStart': True, 'IsEnd': False},
#    {'Id': 2152922, 'Description': 'G8', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2152923, 'Description': 'D9', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2152924, 'Description': 'F13', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2152925, 'Description': 'F15', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2152926, 'Description': 'H18', 'IsStart': False, 'IsEnd': True}]},
#  '372162': {'problem_name': 'MIDTBØ STYLE',
#   'info': ['puga.climbing',
#    'Be the first to repeat this problem',
#    '7B+',
#    'Feet follow hands',
#    '40° MoonBoard'],
#   'url': 'https://moonboard.com/Problems/View/372162/midtb%C3%B8-style',
#   'moves': [{'Id': 2152908,
#     'Description': 'F10',
#     'IsStart': False,
#     'IsEnd': False},
#    {'Id': 2152909, 'Description': 'I14', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2152910, 'Description': 'G18', 'IsStart': False, 'IsEnd': True},
#    {'Id': 2152911, 'Description': 'K5', 'IsStart': True, 'IsEnd': False},
#    {'Id': 2152912, 'Description': 'J8', 'IsStart': False, 'IsEnd': False}]},
#  '372161': {'problem_name': 'MAKE ME BENCHMARK',
#   'info': ['puga.climbing',
#    '7 climbers have repeated this problem',
#    '6B',
#    'Feet follow hands',
#    '40° MoonBoard'],
#   'url': 'https://moonboard.com/Problems/View/372161/make-me-benchmark',
#   'moves': [{'Id': 2152899,
#     'Description': 'H5',
#     'IsStart': True,
#     'IsEnd': False},
#    {'Id': 2152900, 'Description': 'D5', 'IsStart': True, 'IsEnd': False},
#    {'Id': 2152901, 'Description': 'F6', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2152902, 'Description': 'I7', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2152903, 'Description': 'H9', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2152904, 'Description': 'J11', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2152905, 'Description': 'H14', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2152906, 'Description': 'H15', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2152907, 'Description': 'F18', 'IsStart': False, 'IsEnd': True}]},
#  '372160': {'problem_name': 'YELLOW BELLOW',
#   'info': ['puga.climbing',
#    'Be the first to repeat this problem',
#    '7B+',
#    'Feet follow hands',
#    '40° MoonBoard'],
#   'url': 'https://moonboard.com/Problems/View/372160/yellow-bellow',
#   'moves': [{'Id': 2152894,
#     'Description': 'C4',
#     'IsStart': True,
#     'IsEnd': False},
#    {'Id': 2152895, 'Description': 'F13', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2152896, 'Description': 'C10', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2152897, 'Description': 'F16', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2152898, 'Description': 'I18', 'IsStart': False, 'IsEnd': True}]},
#  '372159': {'problem_name': 'LINEA RECTA',
#   'info': ['puga.climbing',
#    '2 climbers have repeated this problem',
#    '6B+',
#    'Feet follow hands',
#    '40° MoonBoard'],
#   'url': 'https://moonboard.com/Problems/View/372159/linea-recta',
#   'moves': [{'Id': 2152889,
#     'Description': 'E6',
#     'IsStart': True,
#     'IsEnd': False},
#    {'Id': 2152890, 'Description': 'H4', 'IsStart': True, 'IsEnd': False},
#    {'Id': 2152891, 'Description': 'G10', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2152892, 'Description': 'E13', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2152893, 'Description': 'F18', 'IsStart': False, 'IsEnd': True}]},
#  '372158': {'problem_name': 'THREE STARS',
#   'info': ['puga.climbing',
#    'Be the first to repeat this problem',
#    '7B',
#    'Feet follow hands',
#    '40° MoonBoard'],
#   'url': 'https://moonboard.com/Problems/View/372158/three-stars',
#   'moves': [{'Id': 2152883,
#     'Description': 'H6',
#     'IsStart': True,
#     'IsEnd': False},
#    {'Id': 2152884, 'Description': 'F4', 'IsStart': True, 'IsEnd': False},
#    {'Id': 2152885, 'Description': 'E9', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2152886, 'Description': 'F13', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2152887, 'Description': 'D16', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2152888, 'Description': 'G18', 'IsStart': False, 'IsEnd': True}]},
#  '372157': {'problem_name': 'ONDRA STYLE',
#   'info': ['puga.climbing',
#    '1 climber has repeated this problem',
#    '7A',
#    'Feet follow hands',
#    '40° MoonBoard'],
#   'url': 'https://moonboard.com/Problems/View/372157/ondra-style',
#   'moves': [{'Id': 2152877,
#     'Description': 'A5',
#     'IsStart': True,
#     'IsEnd': False},
#    {'Id': 2152878, 'Description': 'F5', 'IsStart': True, 'IsEnd': False},
#    {'Id': 2152879, 'Description': 'C10', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2152880, 'Description': 'F12', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2152881, 'Description': 'E15', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2152882, 'Description': 'G18', 'IsStart': False, 'IsEnd': True}]},
#  '372156': {'problem_name': 'KNEE BOARD',
#   'info': ['puga.climbing',
#    'Be the first to repeat this problem',
#    '6C+',
#    'Feet follow hands',
#    '40° MoonBoard'],
#   'url': 'https://moonboard.com/Problems/View/372156/knee-board',
#   'moves': [{'Id': 2152870,
#     'Description': 'F6',
#     'IsStart': True,
#     'IsEnd': False},
#    {'Id': 2152871, 'Description': 'H5', 'IsStart': True, 'IsEnd': False},
#    {'Id': 2152872, 'Description': 'J11', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2152873, 'Description': 'J3', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2152874, 'Description': 'H14', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2152875, 'Description': 'J16', 'IsStart': False, 'IsEnd': False},
#    {'Id': 2152876, 'Description': 'G18', 'IsStart': False, 'IsEnd': True}]}}

# %%
import json

# Serialize data into file:
with open('problems1.json', 'w') as fp:
    json.dump(problems_dict, fp)

# %%
# Read data from file:
with open('problems1.json', 'r') as fp:
    test = json.load(fp)
